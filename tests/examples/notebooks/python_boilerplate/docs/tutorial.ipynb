# %% [markdown]
# # Tutorial

# %%
# NBVAL_IGNORE_OUTPUT
# %load_ext watermark
import python_boilerplate
# %watermark -v --iversions
# Out:
# python_boilerplate  0.1.0-dev
# CPython 3.6.7
# IPython 7.1.1

# %% [markdown]
# $\newcommand{Re}[0]{\operatorname{Re}}
# \newcommand{Im}[0]{\operatorname{Im}}
# \newcommand{dd}[0]{\,\text{d}}
# \newcommand{abs}[0]{\operatorname{abs}}$

# %% [markdown]
# This notebooks illustrates the basic use of the `python_boilerplate` package.

# %%
python_boilerplate.__version__
# Out:
# '0.1.0-dev'

# %%
python_boilerplate.__doc__
# Out:
# 'Top-level package for Python Boilerplate.'

# %% [markdown]
# **TODO**...
